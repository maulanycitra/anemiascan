# %%
# pip freeze
# Out:
# absl-py==2.1.0
# aggdraw==1.3.18.post0
# aiobotocore @ file:///C:/b/abs_3cwz1w13nn/croot/aiobotocore_1701291550158/work
# aiohttp @ file:///C:/b/abs_27h_1rpxgd/croot/aiohttp_1707342354614/work
# aioitertools @ file:///tmp/build/80754af9/aioitertools_1607109665762/work
# aiosignal @ file:///tmp/build/80754af9/aiosignal_1637843061372/work
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work
# altair @ file:///C:/b/abs_27reu1igbg/croot/altair_1687526066495/work
# anaconda-anon-usage @ file:///C:/b/abs_95v3x0wy8p/croot/anaconda-anon-usage_1697038984188/work
# anaconda-catalogs @ file:///C:/b/abs_8btyy0o8s8/croot/anaconda-catalogs_1685727315626/work
# anaconda-client @ file:///C:/b/abs_34txutm0ue/croot/anaconda-client_1708640705294/work
# anaconda-cloud-auth @ file:///C:/b/abs_410afndtyf/croot/anaconda-cloud-auth_1697462767853/work
# anaconda-navigator @ file:///C:/b/abs_cfvv8k_j21/croot/anaconda-navigator_1704813334508/work
# ...

# %%
# pip freeze > require.txt     > untuk get semua library, disimpan di file require.txt
# pip install -r require.txt   > install semua library dari hasil freeze

# %%
import tensorflow as tf
from keras.layers import TFSMLayer
import numpy as np
from tensorflow.keras.preprocessing import image

# Load model dari SavedModel
model = TFSMLayer('saved_model', call_endpoint='serving_default')

# Load labels
with open('tflite/label.txt', 'r') as f:
    labels = f.read().splitlines()

# Function untuk preprocessing gambar
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = img_array / 255.0  # Normalisasi
    img_array = np.expand_dims(img_array, axis=0)  # Tambah batch dimension
    return img_array

# Path gambar (dari Google Drive)
img_paths = [
    'img/abimanyuu.jpg',
    'img/gatott.jpg',
    'img/petruk.jpg',
    'img/kresnaa.jpg',
    'img/kres_p.jpg',
    'img/kress.png'
]

# Prediksi semua gambar
for img_path in img_paths:
    img_array = preprocess_image(img_path)
    preds_dict = model(img_array)      # hasilnya dict
    preds = preds_dict['output_0'].numpy()  # ambil tensor dari dict, lalu numpy

    # Top-5 predictions
    top5_indices = preds[0].argsort()[-5:][::-1]
    top5_labels = [(labels[i], preds[0][i] * 100) for i in top5_indices]

    print(f"Prediksi untuk gambar: {img_path}")
    for label, prob in top5_labels:
        print(f"- {label}: {prob:.2f}%")
    print()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       7 model = TFSMLayer('saved_model', call_endpoint='serving_default')
#       9 # Load labels
# ---> 10 with open('tflite/label.txt', 'r') as f:
#      11     labels = f.read().splitlines()
#      13 # Function untuk preprocessing gambar
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tflite/label.txt'

# %%
# Masukkan semua paragraf kamu ke dalam list
paragraf_list = [
    "TensorFlow digunakan untuk merancang dan melatih model klasifikasi gambar tokoh wayang menggunakan arsitektur CNN. TensorFlow mendukung proses training model deep learning, pengaturan optimizer, dan perhitungan akurasi selama evaluasi model.",
    "Scikit-learn digunakan dalam evaluasi performa model, terutama untuk membuat confusion matrix dan classification report. Library ini membantu mengukur kinerja klasifikasi seperti precision, recall, dan F1-score pada prediksi gambar.",
    "Matplotlib dipakai untuk memvisualisasikan grafik akurasi dan loss selama proses pelatihan model. Selain itu, Matplotlib digunakan untuk menampilkan confusion matrix agar performa model dapat dianalisis secara visual.",
    "NumPy digunakan untuk manipulasi data numerik seperti array, normalisasi pixel gambar, dan membantu pengolahan batch data yang akan digunakan dalam proses training model deep learning.",
    "OS digunakan untuk navigasi file dan folder dataset gambar. Dengan OS, program dapat membuka, membaca, dan mengelola struktur direktori dataset secara otomatis.",
    "OpenCV dimanfaatkan dalam preprocessing gambar, seperti resizing, konversi warna, dan augmentasi sederhana. OpenCV memastikan gambar siap diproses oleh model dalam ukuran dan format yang sesuai.",
    "PIL digunakan untuk membuka gambar, membaca ukuran resolusi, dan memvalidasi file gambar dalam dataset. Dengan PIL, kami memeriksa variasi resolusi gambar sebelum pelatihan model.",
    "Shutil digunakan untuk memindahkan dan mengorganisir file gambar ke dalam struktur folder yang sesuai, seperti memisahkan data training dan testing, atau mengelola hasil klasifikasi gambar.",
    "Seaborn digunakan untuk membuat visualisasi yang lebih informatif seperti heatmap dari confusion matrix. Seaborn membantu dalam memperjelas hubungan prediksi model dan label sebenarnya.",
    "Random digunakan untuk melakukan pembagian data secara acak, seperti saat membuat subset dari dataset untuk validasi, atau untuk mengacak urutan gambar sebelum training.",
    "Google Colab menjadi platform utama untuk pengembangan dan pelatihan model. Dengan dukungan GPU dari Google Colab, pelatihan dataset wayang berukuran besar dapat dilakukan lebih cepat dan efisien.",
    "Pandas digunakan untuk mengelola metadata terkait label gambar dan membuat dataframe yang menyimpan informasi hasil prediksi dan evaluasi model untuk keperluan analisis lebih lanjut."
]

# Cek jumlah kata per paragraf
for i, paragraf in enumerate(paragraf_list, start=1):
    word_count = len(paragraf.split())
    status = "✅ OK" if word_count <= 50 else "❌ Terlalu Panjang"
    print(f"Paragraf {i}: {word_count} kata - {status}")
# Out:
# Paragraf 1: 29 kata - ✅ OK
# Paragraf 2: 28 kata - ✅ OK
# Paragraf 3: 27 kata - ✅ OK
# Paragraf 4: 25 kata - ✅ OK
# Paragraf 5: 22 kata - ✅ OK
# Paragraf 6: 25 kata - ✅ OK
# Paragraf 7: 24 kata - ✅ OK
# Paragraf 8: 25 kata - ✅ OK
# Paragraf 9: 23 kata - ✅ OK
# Paragraf 10: 23 kata - ✅ OK
# Paragraf 11: 27 kata - ✅ OK
# Paragraf 12: 24 kata - ✅ OK
